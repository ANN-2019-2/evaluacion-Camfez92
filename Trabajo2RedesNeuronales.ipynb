# %% [markdown]
# Se cargan las librerias

# %%
import pandas as pd
import numpy as np

import sklearn.linear_model
from sklearn.model_selection import train_test_split 
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn import metrics
from sklearn.neural_network import MLPRegressor
from sklearn.metrics import median_absolute_error, r2_score
from scipy import stats
from patsy import dmatrices
from collections import OrderedDict
import itertools
import statsmodels.formula.api as smf
import sys
import matplotlib.pyplot as plt

# %% [markdown]
# Se cargan los datos

# %%
data=pd.read_csv("https://github.com/ANN-2019-2/evaluacion-Camfez92/blob/master/datos/diabetes.csv?raw=true",sep = ',',         # separador de campos
    thousands = None,  # separador de miles para números
    decimal = '.')     # separador de los decimales para números

# %% [markdown]
# Ahora, veamos de manera descriptiva como se relacionan las variables con la Diabetis "Y"

# %%
plt.figure(figsize=(15,20))
plt.subplot(4, 3, 1)
plt.scatter(data["age"], data["Y"]);
plt.title('AGE vs Y')
plt.xlabel('age')
plt.ylabel('Y')

plt.subplot(4, 3, 2)
plt.scatter(data["sex"], data["Y"]);
plt.title('SEX vs Y')
plt.xlabel('sex')
plt.ylabel('Y')

plt.subplot(4,3,3)
plt.scatter(data["bmi"], data["Y"]);
plt.title('BMI vs Y')
plt.xlabel('bmi')
plt.ylabel('Y')

plt.subplot(4,3,4)
plt.scatter(data["bp"], data["Y"]);
plt.title('BP vs Y')
plt.xlabel('bp')
plt.ylabel('Y')

plt.subplot(4,3,5)
plt.scatter(data["s1"], data["Y"]);
plt.title('S1 vs Y')
plt.xlabel('s1')
plt.ylabel('Y')

plt.subplot(4,3,6)
plt.scatter(data["s2"], data["Y"]);
plt.title('S2 vs Y')
plt.xlabel('s2')
plt.ylabel('Y')

plt.subplot(4,3,7)
plt.scatter(data["s3"], data["Y"]);
plt.title('S3 vs Y')
plt.xlabel('s3')
plt.ylabel('Y')

plt.subplot(4,3,8)
plt.scatter(data["s4"], data["Y"]);
plt.title('S4 vs Y')
plt.xlabel('s4')
plt.ylabel('Y')

plt.subplot(4,3,9)
plt.scatter(data["s5"], data["Y"]);
plt.title('S5 vs Y')
plt.xlabel('s5')
plt.ylabel('Y')

plt.subplot(4,3,10)
plt.scatter(data["s6"], data["Y"]);
plt.title('S6 vs Y')
plt.xlabel('s6')
plt.ylabel('Y')

plt.show()

# %% [markdown]
# Es dificil ver que exista relación entre las variables.
#
# Apliquemos Akaike, busquemos el modelo que mejor se adapte basandonos en el AIC.
#
# El siguiente código fue obtenido de:
# https://towardsdatascience.com/the-akaike-information-criterion-c20c8fd832f2
#
# y fue adaptado para el propósito de este trabajo, los nombres de las variables se cambiaron así:
#
# age=TAVG_LAG_1, sex=TAVG_LAG_2, bmi=TAVG_LAG_3, bp=TAVG_LAG_4, s1=TAVG_LAG_5, s2=TAVG_LAG_6, s3=TAVG_LAG_7, s4=TAVG_LAG_8, s5=TAVG_LAG_9, s6=TAVG_LAG_10

# %%
df_lagged=data.copy()
df_lagged.columns=["TAVG_LAG_1","TAVG_LAG_2","TAVG_LAG_3","TAVG_LAG_4","TAVG_LAG_5","TAVG_LAG_6","TAVG_LAG_7","TAVG_LAG_8","TAVG_LAG_9","TAVG_LAG_10","TAVG"]

split_index = round(len(df_lagged)*0.8)
split_date = df_lagged.index[split_index]
df_train = df_lagged.loc[df_lagged.index <= split_date].copy()
df_test = df_lagged.loc[df_lagged.index > split_date].copy()

lag_combinations = OrderedDict()
l = list(range(1,11,1))

for i in range(1, 11, 1):
   for combination in itertools.combinations(l, i):
      lag_combinations[combination] = 0.0



#Current minimum AIC score
min_aic = sys.float_info.max
#Model expression for the best model seen so far
best_expr = ''
#OLSResults objects for the best model seen so far
best_olsr_model_results = None

expr_prefix = 'TAVG ~ '
#Run through each lag combination
for combination in lag_combinations:
  expr = expr_prefix
   
  i = 1
   #Build the model's expression in patsy notation, for e.g. 'TAVG ~ TAVG_LAG_1 + TAVG_LAG_2' represents a model containing two lag variables and TAVG_LAG_1 and TAVG_LAG_2 plus the intercept
  for lag_num in combination:
    if i < len(combination):
      expr = expr + 'TAVG_LAG_' + str(lag_num) + ' + '
    else:
      expr = expr + 'TAVG_LAG_' + str(lag_num)

    i += 1

  print('Building OLSR model for expr: ' + expr)

    
    #Build and fit the OLSR model using statsmodels
  olsr_results = smf.ols(expr, df_train).fit()

    #Store away the model's AIC score
  lag_combinations[combination] = olsr_results.aic
  print('AIC='+str(lag_combinations[combination]))
  #If the model's AIC score is less than the current minimum score, update the current minimum AIC score and the current best model
  if olsr_results.aic < min_aic:
    min_aic = olsr_results.aic
    best_expr = expr
    best_olsr_model_results = olsr_results
# Out:
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1
# AIC=4078.0142444737357
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2
# AIC=4088.618470478722
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3
# AIC=3941.1474659073747
# Building OLSR model for expr: TAVG ~ TAVG_LAG_4
# AIC=4018.900380889396
# Building OLSR model for expr: TAVG ~ TAVG_LAG_5
# AIC=4068.4901611818486
# Building OLSR model for expr: TAVG ~ TAVG_LAG_6
# AIC=4074.0844756154984
# Building OLSR model for expr: TAVG ~ TAVG_LAG_7
# AIC=4032.1982100101723
# Building OLSR model for expr: TAVG ~ TAVG_LAG_8
# AIC=4011.055661127505
# Building OLSR model for expr: TAVG ~ TAVG_LAG_9
# AIC=3949.8235990896483
# Building OLSR model for expr: TAVG ~ TAVG_LAG_10
# AIC=4027.53247126085
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2
# AIC=4079.985878709036
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3
# AIC=3941.376555888789
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_4
# AIC=4020.154644959651
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_5
# AIC=4065.6502294288557
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_6
# AIC=4069.7579704742147
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_7
# AIC=4023.7721488177576
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_8
# AIC=4009.333173664909
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_9
# AIC=3951.3868254069794
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_10
# AIC=4027.9108217172097
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3
# AIC=3942.757572235265
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_4
# AIC=4018.5953483585763
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_5
# AIC=4070.3429201812023
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_6
# AIC=4076.0776393355954
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_7
# AIC=4026.6689938122845
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_8
# AIC=4006.0468305610357
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_9
# AIC=3951.0434563593117
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_10
# AIC=4027.1997219659534
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_4
# AIC=3918.919666964148
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_5
# AIC=3940.590044141776
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_6
# AIC=3942.903525790329
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_7
# AIC=3924.576622862317
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_8
# AIC=3920.1363987617087
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_9
# AIC=3875.370497406332
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_10
# AIC=3925.444243307178
# Building OLSR model for expr: TAVG ~ TAVG_LAG_4 + TAVG_LAG_5
# AIC=4013.9026147953255
# Building OLSR model for expr: TAVG ~ TAVG_LAG_4 + TAVG_LAG_6
# AIC=4015.239090447835
# Building OLSR model for expr: TAVG ~ TAVG_LAG_4 + TAVG_LAG_7
# AIC=3972.9611621419235
# Building OLSR model for expr: TAVG ~ TAVG_LAG_4 + TAVG_LAG_8
# AIC=3965.033644760485
# Building OLSR model for expr: TAVG ~ TAVG_LAG_4 + TAVG_LAG_9
# AIC=3925.4411428495687
# Building OLSR model for expr: TAVG ~ TAVG_LAG_4 + TAVG_LAG_10
# AIC=3992.375111044048
# Building OLSR model for expr: TAVG ~ TAVG_LAG_5 + TAVG_LAG_6
# AIC=4070.3318492942244
# Building OLSR model for expr: TAVG ~ TAVG_LAG_5 + TAVG_LAG_7
# AIC=4005.577485317096
# Building OLSR model for expr: TAVG ~ TAVG_LAG_5 + TAVG_LAG_8
# AIC=4013.055387734493
# Building OLSR model for expr: TAVG ~ TAVG_LAG_5 + TAVG_LAG_9
# AIC=3948.9203784742867
# Building OLSR model for expr: TAVG ~ TAVG_LAG_5 + TAVG_LAG_10
# AIC=4025.1771387433273
# Building OLSR model for expr: TAVG ~ TAVG_LAG_6 + TAVG_LAG_7
# AIC=4027.8958587292227
# Building OLSR model for expr: TAVG ~ TAVG_LAG_6 + TAVG_LAG_8
# AIC=4006.6559829908274
# Building OLSR model for expr: TAVG ~ TAVG_LAG_6 + TAVG_LAG_9
# AIC=3951.7269253958057
# Building OLSR model for expr: TAVG ~ TAVG_LAG_6 + TAVG_LAG_10
# AIC=4026.910026021408
# Building OLSR model for expr: TAVG ~ TAVG_LAG_7 + TAVG_LAG_8
# AIC=4010.1652618693934
# Building OLSR model for expr: TAVG ~ TAVG_LAG_7 + TAVG_LAG_9
# AIC=3933.9485258952727
# Building OLSR model for expr: TAVG ~ TAVG_LAG_7 + TAVG_LAG
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_9
# AIC=3853.1225139133285
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_10
# AIC=3863.3173783750335
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3852.3135169956167
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3875.7901851239703
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3851.931715380111
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3853.0424552945615
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3886.449867965205
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3852.0042677728698
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3852.5061776777757
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3853.9272622575427
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3877.9429711001894
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3852.5734834001496
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3857.449973931286
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3854.4786194844464
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3870.7088689429975
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3880.489532753244
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3867.529417375663
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3867.3721384776554
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3867.8685940389414
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3868.477939498104
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3899.085095901113
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3913.5599258797556
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3895.684280324813
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3894.980496796429
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3897.321622919265
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3898.112178941469
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3924.7345206050277
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3863.617793961301
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3876.501772782487
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3863.329440847354
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3863.1316528710704
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3863.7014307256222
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3864.4673712363438
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3875.0463137213583
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3912.760770400959
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3852.3104165102313
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3863.1526858245797
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3851.522754930943
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3850.8709080137287
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3851.563285851338
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3852.4515764370562
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3867.6116904019364
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3894.981078433171
# Building OLSR model for expr: TAVG ~ TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3863.423283258834
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9
# AIC=3854.308204033483
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_10
# AIC=3865.1437809905274
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3853.491688156895
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3852.841893091837
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3853.54822056996
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3854.435485899313
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3869.3606029733946
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3896.980476234513
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3865.0344267678047
# Building OLSR model for expr: TAVG ~ TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3852.8701919778086
# Building OLSR model for expr: TAVG ~ TAVG_LAG_1 + TAVG_LAG_2 + TAVG_LAG_3 + TAVG_LAG_4 + TAVG_LAG_5 + TAVG_LAG_6 + TAVG_LAG_7 + TAVG_LAG_8 + TAVG_LAG_9 + TAVG_LAG_10
# AIC=3854.8404410495577

# %% [markdown]
# Ahora, veamos el mejor modelo:

# %%
print(best_olsr_model_results.summary())

# %% [markdown]
# Lo que resulta que las variables sexo, índice de masa corporal, presión sanguinea, s1,s2 y s5 tienen por lo menos un 95% de confianza segun t-test y el AIC menor encontrado fue en esta combinación, con un valor de aproximadamente 3850 y, por lo tanto, es nuestra mejor combinación de variables.
#
# Nuestro Modelo lineal quedaría de la siguiente forma:
#
# *Yi=W0 + W1*X1i + W2*X2i + W3*X3i + W4*X4i + W5*X5i + W6*X6i*
#
# Donde:
#
# *   X1=sex
# *   X2=bmi
# *   X3=bp
# *   X4=S1
# *   X5=S2
# *   X6=S5

# %% [markdown]
# Con statsmodel podemos extraer los coeficientes y hallar predicciones, quedemonos con las variables independientes importantes para nuestro modelo y apliquemos cross-validation

# %%
X=data[["sex","bmi","bp","s1","s2","s5"]]
Y=data["Y"]

X_train, X_test, y_train, y_test = train_test_split(X, Y, test_size=0.25)

lm = sklearn.linear_model.LinearRegression()
model = lm.fit(X_train, y_train)
print("Intercepto: ",model.intercept_)
print("Coeficientes del modelo: ",model.coef_)
# Out:
# Intercepto:  151.1670380851621
# Coeficientes del modelo:  [-250.29168619  512.05698015  347.1236527  -706.54342062  451.06148685
#   758.92910216]

# %%
scores = cross_val_score(model, X, Y, cv=4)
print ("Cross-validated scores:", scores)
predictions = cross_val_predict(model, X, Y, cv=4)
# Out:
# Cross-validated scores: [0.3775882  0.49824774 0.52008326 0.56331318]

# %% [markdown]
# Ahora, veamos los resultados

# %%
plt.figure(figsize=(20,10))
#plt.subplot(2, 1, 1)
plt.plot(predictions,"Blue");
#plt.title("PREDICCIONES")
#plt.subplot(2, 1, 2)
plt.plot(Y,"Red");
#plt.title('Y REAL')

print("R2 = ",r2_score(Y,predictions))
print("Error medio absoluto = ",median_absolute_error(Y, predictions))
# Out:
# R2 =  0.5057389395954441
# Error medio absoluto =  37.965823429711946
